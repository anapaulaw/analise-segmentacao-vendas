# %%
import sqlite3
import pandas as pd

# %%
dados_brutos = pd.read_excel("vendas.xlsx")

# %%
variaveis_desejadas = [
    'DATA E HORA',
    'NaturezaOperacao',
    'DEPARTAMENTO QUE VENDEU (OFICINA OU BALCÃO)',
    'CONDIÇÃO DE PAGAMENTO',
    'NFItem_PercDesc',
    'NFItem_QtdeEstoque',
    'NFItem_VlMargemCont',
    'NOME DA PEÇA',
    'VENDEDOR',
    'NFItem_VlDesc',
    'QUANTIDADE',
    'VALOR UNITÁRIO',
    'NF_ProdCusto',
    'ProdPrecoValor',
    'ProdEstoqueClasABC',
    'ValorICMS',
    'ValorICMSST',
    'ValorPisCofins',
    'ValorLucroBruto',
    'VALOR DA VENDA',
    'NFItem_VlBruto',
    'NFItem_PercMargemCont',
    'NFItem_PercMargemGer'
]

df_filtrado = dados_brutos[variaveis_desejadas].copy()

# %% [markdown]
# ### CRIAR BANCO SQLITE COM DADOS FILTRADOS
#
# ---

# %%
conn = sqlite3.connect("vendas_filtradas.db")
df_filtrado.to_sql("vendas", conn, if_exists="replace", index=False)
print("✅ Banco SQLite criado: vendas_filtradas.db")
# Out:
# ✅ Banco SQLite criado: vendas_filtradas.db

# %%
#SALVAR  os dados também em Excel
df_filtrado.to_excel("vendas_filtradas.xlsx", index=False)
print("✅ Arquivo Excel criado: vendas_filtradas.xlsx")
# Out:
# ✅ Arquivo Excel criado: vendas_filtradas.xlsx

# %% [markdown]
# ### EXEMPLOS DE EXPLORAÇÃO UTILIZANDO SQL
#
# ---

# %%
consulta1 = pd.read_sql("""
    SELECT VENDEDOR, SUM("VALOR DA VENDA") AS Total_Vendas
    FROM vendas
    GROUP BY VENDEDOR
""", conn)

# %%
print("\n🔎 Vendas por vendedor:")
display(consulta1)
# Out:
# 🔎 Vendas por vendedor:
#    VENDEDOR  Total_Vendas
# 0       ANA     529656.34
# 1  FERNANDO     213692.39
# 2     ICARO    1239147.74
# 3   ISABELA       2780.00
# 4      JOAO     578674.89
# 5   LEANDRO     478802.96
# 6    STELLA     985124.34

# %%
consulta2 = pd.read_sql("""
    SELECT "DEPARTAMENTO QUE VENDEU (OFICINA OU BALCÃO)" AS Departamento,
           COUNT(*) AS Qtde_Vendas,
           SUM("VALOR DA VENDA") AS Total_Departamento
    FROM vendas
    GROUP BY Departamento
""", conn)



print("\n🔎 Vendas por departamento:")
display(consulta2)
# Out:
# 🔎 Vendas por departamento:
#   Departamento  Qtde_Vendas  Total_Departamento
# 0          BLC         4937          2199684.97
# 1          OFI         5038          1828193.69

# %%
# Fechar conexão com o banco
conn.close()
